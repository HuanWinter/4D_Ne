# %%
# import package

import numpy as np
import os
import netCDF4 as nc
import linecache as lc

# %%
# list the RO files
path = '/export/scratch2/andong/Data/ROdata/cosmic2013/ionPrf/2010.182/'
files = []
lists = open("cosmic_list.txt","w")
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.nc' in file:
            files.append(os.path.join(r, file))

for f in files:
    lists.write("%s\n"%f)
lists.close()

# %%
# how many lines/files in the list
count = -1
for count, line in enumerate(open("cosmic_list.txt","r")):
    pass
count +=1
count
# Out:
# 1757

# %%
# read the RO files

f = open("cosmic_list.txt","r")
#for path in open("cosmic_list.txt","r"):
for i in count:
    print(i)
    path = f.readline()
    path=path.strip('\n')
    file = nc.Dataset(path)
    print(file.variables.keys())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-27b4b31f59dc> in <module>
#       3 f = open("cosmic_list.txt","r")
#       4 #for path in open("cosmic_list.txt","r"):
# ----> 5 for i in count:
#       6     print(i)
#       7     path = f.readline()
#
# TypeError: 'int' object is not iterable

# %%
str = lc.getlines("cosmic_list.txt")
print(str[0])
len(str)
# Out:
# /export/scratch2/andong/Data/ROdata/cosmic2013/ionPrf/2010.182/ionPrf_C003.2010.182.17.13.G20_2013.3520.nc
# 1757

# %%
for i in range(len(str)):
    path = str[i]
    path = path.strip('\n')
    file = nc.Dataset(path)
    #print(file.variables.keys())
    #print(file.ncattrs)
    for attr in file.ncattrs():
        print(attr)
        year[i] =
# Out:
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# ...
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
# occ_id
# fiducial_id
# reference_sat_id
# occulting_sat_id
# year
# month
# day
# hour
# minute
# second
# offset
# shortlen
# setting
# icalib
# botnum
# bottime
# botlct
# botalt
# botlat
# botlon
# botaz
# topnum
# toptime
# toplct
# topalt
# toplat
# toplon
# topaz
# edmaxtime
# edmaxlct
# edmaxalt
# edmaxlat
# edmaxlon
# edmaxaz
# smear
# edmax
# critfreq
# tec0
# tec1
# edorbtime
# edorbalt
# edorb
# hscale
# topfit
# nmax
# fileStamp
# inverter
# parmsfile
# center
# mission
# creation_time
